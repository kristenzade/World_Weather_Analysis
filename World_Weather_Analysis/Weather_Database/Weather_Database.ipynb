# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import timeit
import json
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f3f475362dfa999873f1396f680bbfdf

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs= np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 619

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | fortuna
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | ballina
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | andenes
# Processing Record 16 of Set 1 | mpika
# Processing Record 17 of Set 1 | hualmay
# Processing Record 18 of Set 1 | husavik
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | newport
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | zhuzhou
# Processing Record 23 of Set 1 | nelson bay
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | ixtapa
# Processing Record 28 of Set 1 | hokitika
# Processing Record 29 of Set 1 | aukra
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | sao gabriel da cachoeira
# Processing Record 32 of Set 1 | bonavista
# Processing Record 33 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 1 | chuy
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | houma
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | pierre
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | asau
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | bengkulu
# Processing Record 43 of Set 1 | the valley
# Processing Record 44 of Set 1 | beihai
# Processing Record 45 of Set 1 | krasnystaw
# Processing Record 46 of Set 1 | bom jesus
# Processing Record 47 of Set 1 | donskoye
# Processing Record 48 of Set 1 | saravan
# Processing Record 49 of Set 1 | billings
# Processing Record 50 of Set 1 | guerrero negro
# Processing Record 1 of Set 2 | dingle
# Processing Record 2 of Set 2 | kupang
# Processing Record 3 of Set 2 | pangnirtung
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 2 | qaqortoq
# Processing Record 7 of Set 2 | kavieng
# Processing Record 8 of Set 2 | port pirie
# Processing Record 9 of Set 2 | sile
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | kalaiya
# Processing Record 12 of Set 2 | skeldon
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | pecanha
# Processing Record 15 of Set 2 | zapadnaya dvina
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | caruray
# Processing Record 19 of Set 2 | naze
# Processing Record 20 of Set 2 | roma
# Processing Record 21 of Set 2 | srednekolymsk
# Processing Record 22 of Set 2 | verkhnyaya inta
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | molchanovo
# Processing Record 25 of Set 2 | klaksvik
# Processing Record 26 of Set 2 | lebu
# Processing Record 27 of Set 2 | san patricio
# Processing Record 28 of Set 2 | kamenka
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | valle del guamuez
# Processing Record 31 of Set 2 | vodnyy
# Processing Record 32 of Set 2 | camacha
# Processing Record 33 of Set 2 | vila do maio
# Processing Record 34 of Set 2 | yulara
# Processing Record 35 of Set 2 | cabo san lucas
# Processing Record 36 of Set 2 | general roca
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | marsh harbour
# Processing Record 39 of Set 2 | port lincoln
# Processing Record 40 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 2 | sept-iles
# Processing Record 43 of Set 2 | montepuez
# Processing Record 44 of Set 2 | constitucion
# Processing Record 45 of Set 2 | lasa
# Processing Record 46 of Set 2 | san juan
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | cockburn town
# Processing Record 49 of Set 2 | sipovo
# Processing Record 50 of Set 2 | dikson
# Processing Record 1 of Set 3 | oksfjord
# Processing Record 2 of Set 3 | san quintin
# Processing Record 3 of Set 3 | clyde river
# Processing Record 4 of Set 3 | tuatapere
# Processing Record 5 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 3 | sarkand
# Processing Record 7 of Set 3 | joao pinheiro
# Processing Record 8 of Set 3 | esperance
# Processing Record 9 of Set 3 | teyateyaneng
# Processing Record 10 of Set 3 | kenai
# Processing Record 11 of Set 3 | semey
# Processing Record 12 of Set 3 | tiarei
# Processing Record 13 of Set 3 | tortoli
# Processing Record 14 of Set 3 | maputo
# Processing Record 15 of Set 3 | kurumkan
# Processing Record 16 of Set 3 | lorengau
# Processing Record 17 of Set 3 | norman wells
# Processing Record 18 of Set 3 | souillac
# Processing Record 19 of Set 3 | bahia blanca
# Processing Record 20 of Set 3 | college
# Processing Record 21 of Set 3 | vila velha
# Processing Record 22 of Set 3 | sovetskiy
# Processing Record 23 of Set 3 | rosario oeste
# Processing Record 24 of Set 3 | longyearbyen
# Processing Record 25 of Set 3 | ucluelet
# Processing Record 26 of Set 3 | rocha
# Processing Record 27 of Set 3 | vostok
# Processing Record 28 of Set 3 | yaan
# Processing Record 29 of Set 3 | gorontalo
# Processing Record 30 of Set 3 | lagoa
# Processing Record 31 of Set 3 | puerto ayora
# Processing Record 32 of Set 3 | pevek
# Processing Record 33 of Set 3 | san cristobal
# Processing Record 34 of Set 3 | senekal
# Processing Record 35 of Set 3 | komsomolsk
# Processing Record 36 of Set 3 | bambous virieux
# Processing Record 37 of Set 3 | chokurdakh
# Processing Record 38 of Set 3 | svetlogorsk
# Processing Record 39 of Set 3 | georgetown
# Processing Record 40 of Set 3 | jamestown
# Processing Record 41 of Set 3 | hithadhoo
# Processing Record 42 of Set 3 | atuona
# Processing Record 43 of Set 3 | valday
# Processing Record 44 of Set 3 | harper
# Processing Record 45 of Set 3 | dunedin
# Processing Record 46 of Set 3 | vidalia
# Processing Record 47 of Set 3 | poum
# Processing Record 48 of Set 3 | bethel
# Processing Record 49 of Set 3 | vaini
# Processing Record 50 of Set 3 | yellowknife
# Processing Record 1 of Set 4 | purpe
# Processing Record 2 of Set 4 | sao jose da coroa grande
# Processing Record 3 of Set 4 | charcas
# Processing Record 4 of Set 4 | chongqing
# Processing Record 5 of Set 4 | popova
# Processing Record 6 of Set 4 | kudahuvadhoo
# Processing Record 7 of Set 4 | aljezur
# Processing Record 8 of Set 4 | santa maria
# Processing Record 9 of Set 4 | flin flon
# Processing Record 10 of Set 4 | takoradi
# Processing Record 11 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 4 | lavrentiya
# Processing Record 13 of Set 4 | half moon bay
# Processing Record 14 of Set 4 | cartagena
# Processing Record 15 of Set 4 | mogadishu
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | viseu
# Processing Record 18 of Set 4 | bogatyr
# Processing Record 19 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 4 | san bartolome de tirajana
# Processing Record 21 of Set 4 | geraldton
# Processing Record 22 of Set 4 | puerto suarez
# Processing Record 23 of Set 4 | iberia
# Processing Record 24 of Set 4 | ahipara
# Processing Record 25 of Set 4 | pouembout
# Processing Record 26 of Set 4 | urdoma
# Processing Record 27 of Set 4 | atar
# Processing Record 28 of Set 4 | gonzalez
# Processing Record 29 of Set 4 | nikolskoye
# Processing Record 30 of Set 4 | cervo
# Processing Record 31 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 4 | graaff-reinet
# Processing Record 33 of Set 4 | bosaso
# Processing Record 34 of Set 4 | kananga
# Processing Record 35 of Set 4 | san luis
# Processing Record 36 of Set 4 | padre paraiso
# Processing Record 37 of Set 4 | komsomolskiy
# Processing Record 38 of Set 4 | singaraja
# Processing Record 39 of Set 4 | aykhal
# Processing Record 40 of Set 4 | haines junction
# Processing Record 41 of Set 4 | lompoc
# Processing Record 42 of Set 4 | mizdah
# Processing Record 43 of Set 4 | maragogi
# Processing Record 44 of Set 4 | valdivia
# Processing Record 45 of Set 4 | tainan
# Processing Record 46 of Set 4 | lexington
# Processing Record 47 of Set 4 | la rioja
# Processing Record 48 of Set 4 | westport
# Processing Record 49 of Set 4 | mahebourg
# Processing Record 50 of Set 4 | sao filipe
# Processing Record 1 of Set 5 | sorrento
# Processing Record 2 of Set 5 | asfi
# Processing Record 3 of Set 5 | castro
# Processing Record 4 of Set 5 | balabac
# Processing Record 5 of Set 5 | kamennomostskiy
# Processing Record 6 of Set 5 | tilichiki
# Processing Record 7 of Set 5 | saint-francois
# Processing Record 8 of Set 5 | north platte
# Processing Record 9 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 5 | goma
# Processing Record 11 of Set 5 | kismayo
# Processing Record 12 of Set 5 | shahr-e babak
# Processing Record 13 of Set 5 | pochutla
# Processing Record 14 of Set 5 | kaitangata
# Processing Record 15 of Set 5 | japura
# Processing Record 16 of Set 5 | grindavik
# Processing Record 17 of Set 5 | sistranda
# Processing Record 18 of Set 5 | medea
# Processing Record 19 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 5 | saint-philippe
# Processing Record 21 of Set 5 | bandarbeyla
# Processing Record 22 of Set 5 | tura
# Processing Record 23 of Set 5 | victoria
# Processing Record 24 of Set 5 | takestan
# Processing Record 25 of Set 5 | jumla
# Processing Record 26 of Set 5 | pacific grove
# Processing Record 27 of Set 5 | butaritari
# Processing Record 28 of Set 5 | padang
# Processing Record 29 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 30 of Set 5 | itamaraca
# Processing Record 31 of Set 5 | tasiilaq
# Processing Record 32 of Set 5 | christchurch
# Processing Record 33 of Set 5 | cabedelo
# Processing Record 34 of Set 5 | zhezkazgan
# Processing Record 35 of Set 5 | manado
# Processing Record 36 of Set 5 | anchorage
# Processing Record 37 of Set 5 | jiutai
# Processing Record 38 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 5 | gazojak
# Processing Record 40 of Set 5 | raudeberg
# Processing Record 41 of Set 5 | namatanai
# Processing Record 42 of Set 5 | kapaa
# Processing Record 43 of Set 5 | byron bay
# Processing Record 44 of Set 5 | plymouth
# Processing Record 45 of Set 5 | lata
# Processing Record 46 of Set 5 | walvis bay
# Processing Record 47 of Set 5 | pak chong
# Processing Record 48 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 5 | bluff
# Processing Record 50 of Set 5 | ribeira grande
# Processing Record 1 of Set 6 | nanortalik
# Processing Record 2 of Set 6 | saint george
# Processing Record 3 of Set 6 | maceio
# Processing Record 4 of Set 6 | korla
# Processing Record 5 of Set 6 | north bend
# Processing Record 6 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 6 | namibe
# Processing Record 8 of Set 6 | ilulissat
# Processing Record 9 of Set 6 | estelle
# Processing Record 10 of Set 6 | arlit
# Processing Record 11 of Set 6 | mana
# Processing Record 12 of Set 6 | cherskiy
# Processing Record 13 of Set 6 | huarmey
# Processing Record 14 of Set 6 | ulladulla
# Processing Record 15 of Set 6 | salinopolis
# Processing Record 16 of Set 6 | catamarca
# Processing Record 17 of Set 6 | yalta
# Processing Record 18 of Set 6 | amahai
# Processing Record 19 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 6 | saint-augustin
# Processing Record 21 of Set 6 | comodoro rivadavia
# Processing Record 22 of Set 6 | kortkeros
# Processing Record 23 of Set 6 | leningradskiy
# Processing Record 24 of Set 6 | kiruna
# Processing Record 25 of Set 6 | bubaque
# Processing Record 26 of Set 6 | praia da vitoria
# Processing Record 27 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 6 | taltal
# Processing Record 29 of Set 6 | yauya
# Processing Record 30 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 6 | gizo
# Processing Record 33 of Set 6 | saint anthony
# Processing Record 34 of Set 6 | ostrovnoy
# Processing Record 35 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 36 of Set 6 | ponta pora
# Processing Record 37 of Set 6 | benito juarez
# Processing Record 38 of Set 6 | khatanga
# Processing Record 39 of Set 6 | bellevue
# Processing Record 40 of Set 6 | vagur
# Processing Record 41 of Set 6 | pandan
# Processing Record 42 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 43 of Set 6 | taoudenni
# Processing Record 44 of Set 6 | straumen
# Processing Record 45 of Set 6 | twin falls
# Processing Record 46 of Set 6 | mehamn
# Processing Record 47 of Set 6 | severo-kurilsk
# Processing Record 48 of Set 6 | nola
# Processing Record 49 of Set 6 | ancud
# Processing Record 50 of Set 6 | santa marta
# Processing Record 1 of Set 7 | tsaratanana
# Processing Record 2 of Set 7 | nam tha
# City not found. Skipping...
# Processing Record 3 of Set 7 | kungurtug
# Processing Record 4 of Set 7 | yantzaza
# Processing Record 5 of Set 7 | mount isa
# Processing Record 6 of Set 7 | kuching
# Processing Record 7 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 7 | vanimo
# Processing Record 9 of Set 7 | turukhansk
# Processing Record 10 of Set 7 | sitka
# Processing Record 11 of Set 7 | pekan
# Processing Record 12 of Set 7 | mayor pablo lagerenza
# Processing Record 13 of Set 7 | corinth
# Processing Record 14 of Set 7 | noumea
# Processing Record 15 of Set 7 | darab
# Processing Record 16 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 7 | caravelas
# Processing Record 18 of Set 7 | monaghan
# Processing Record 19 of Set 7 | alice springs
# Processing Record 20 of Set 7 | labytnangi
# Processing Record 21 of Set 7 | te anau
# Processing Record 22 of Set 7 | nerchinskiy zavod
# Processing Record 23 of Set 7 | ust-nera
# Processing Record 24 of Set 7 | san isidro
# Processing Record 25 of Set 7 | teahupoo
# Processing Record 26 of Set 7 | orlik
# Processing Record 27 of Set 7 | yozgat
# Processing Record 28 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 7 | belyy yar
# Processing Record 30 of Set 7 | sungai siput utara
# City not found. Skipping...
# Processing Record 31 of Set 7 | bafra
# Processing Record 32 of Set 7 | okandja
# City not found. Skipping...
# Processing Record 33 of Set 7 | salta
# Processing Record 34 of Set 7 | lancaster
# Processing Record 35 of Set 7 | martapura
# Processing Record 36 of Set 7 | shakawe
# Processing Record 37 of Set 7 | aban
# Processing Record 38 of Set 7 | mocuba
# Processing Record 39 of Set 7 | ugoofaaru
# Processing Record 40 of Set 7 | mayumba
# Processing Record 41 of Set 7 | magdagachi
# Processing Record 42 of Set 7 | villarrica
# Processing Record 43 of Set 7 | nome
# Processing Record 44 of Set 7 | wellington
# Processing Record 45 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 46 of Set 7 | camana
# Processing Record 47 of Set 7 | propria
# Processing Record 48 of Set 7 | richards bay
# Processing Record 49 of Set 7 | ust-kuyga
# Processing Record 50 of Set 7 | galiakot
# Processing Record 1 of Set 8 | shimoda
# Processing Record 2 of Set 8 | kruisfontein
# Processing Record 3 of Set 8 | ornskoldsvik
# Processing Record 4 of Set 8 | northam
# Processing Record 5 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 8 | kilis
# Processing Record 7 of Set 8 | karatau
# Processing Record 8 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 9 of Set 8 | paamiut
# Processing Record 10 of Set 8 | batagay-alyta
# Processing Record 11 of Set 8 | jishou
# Processing Record 12 of Set 8 | nova olinda do norte
# Processing Record 13 of Set 8 | meulaboh
# Processing Record 14 of Set 8 | mudyuga
# City not found. Skipping...
# Processing Record 15 of Set 8 | kawalu
# Processing Record 16 of Set 8 | macau
# Processing Record 17 of Set 8 | saquena
# Processing Record 18 of Set 8 | bandar-e lengeh
# Processing Record 19 of Set 8 | chernenko
# Processing Record 20 of Set 8 | mujiayingzi
# Processing Record 21 of Set 8 | aborlan
# Processing Record 22 of Set 8 | vao
# Processing Record 23 of Set 8 | carnarvon
# Processing Record 24 of Set 8 | bima
# Processing Record 25 of Set 8 | necochea
# Processing Record 26 of Set 8 | san felipe
# Processing Record 27 of Set 8 | piacabucu
# Processing Record 28 of Set 8 | kavaratti
# Processing Record 29 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 30 of Set 8 | filadelfia
# Processing Record 31 of Set 8 | umm lajj
# Processing Record 32 of Set 8 | mounana
# Processing Record 33 of Set 8 | hailar
# Processing Record 34 of Set 8 | lichuan
# Processing Record 35 of Set 8 | portland
# Processing Record 36 of Set 8 | lillooet
# Processing Record 37 of Set 8 | margate
# Processing Record 38 of Set 8 | gazli
# Processing Record 39 of Set 8 | hasaki
# Processing Record 40 of Set 8 | honningsvag
# Processing Record 41 of Set 8 | rawson
# Processing Record 42 of Set 8 | faya
# Processing Record 43 of Set 8 | peleduy
# Processing Record 44 of Set 8 | baykit
# Processing Record 45 of Set 8 | port moresby
# Processing Record 46 of Set 8 | evensk
# Processing Record 47 of Set 8 | kodinsk
# Processing Record 48 of Set 8 | longhua
# Processing Record 49 of Set 8 | san carlos de bariloche
# Processing Record 50 of Set 8 | fairbanks
# Processing Record 1 of Set 9 | sangmelima
# Processing Record 2 of Set 9 | puerto escondido
# Processing Record 3 of Set 9 | pisco
# Processing Record 4 of Set 9 | zhigansk
# Processing Record 5 of Set 9 | palana
# Processing Record 6 of Set 9 | sambava
# Processing Record 7 of Set 9 | at-bashi
# Processing Record 8 of Set 9 | coquimbo
# Processing Record 9 of Set 9 | ukiah
# Processing Record 10 of Set 9 | galesong
# Processing Record 11 of Set 9 | jawhar
# Processing Record 12 of Set 9 | miri
# Processing Record 13 of Set 9 | kutum
# Processing Record 14 of Set 9 | weihe
# Processing Record 15 of Set 9 | muroto
# Processing Record 16 of Set 9 | upernavik
# Processing Record 17 of Set 9 | storforshei
# Processing Record 18 of Set 9 | katobu
# Processing Record 19 of Set 9 | san antonio
# Processing Record 20 of Set 9 | dolores hidalgo
# Processing Record 21 of Set 9 | mount gambier
# Processing Record 22 of Set 9 | bireun
# Processing Record 23 of Set 9 | bollnas
# Processing Record 24 of Set 9 | urfa
# City not found. Skipping...
# Processing Record 25 of Set 9 | broome
# Processing Record 26 of Set 9 | skelleftea
# Processing Record 27 of Set 9 | tukrah
# Processing Record 28 of Set 9 | omboue
# Processing Record 29 of Set 9 | oriximina
# Processing Record 30 of Set 9 | vilyuysk
# Processing Record 31 of Set 9 | muzhi
# Processing Record 32 of Set 9 | saldanha
# Processing Record 33 of Set 9 | moussoro
# Processing Record 34 of Set 9 | williams lake
# Processing Record 35 of Set 9 | avera
# Processing Record 36 of Set 9 | talnakh
# Processing Record 37 of Set 9 | tevriz
# Processing Record 38 of Set 9 | terney
# Processing Record 39 of Set 9 | awbari
# Processing Record 40 of Set 9 | lundazi
# Processing Record 41 of Set 9 | krasnoselkup
# Processing Record 42 of Set 9 | yanam
# Processing Record 43 of Set 9 | santa rosa
# Processing Record 44 of Set 9 | fort nelson
# Processing Record 45 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 9 | beringovskiy
# Processing Record 47 of Set 9 | praia
# Processing Record 48 of Set 9 | yibin
# Processing Record 49 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 50 of Set 9 | saint-pierre
# Processing Record 1 of Set 10 | cananea
# Processing Record 2 of Set 10 | nyanza
# Processing Record 3 of Set 10 | olafsvik
# Processing Record 4 of Set 10 | deputatskiy
# Processing Record 5 of Set 10 | okha
# Processing Record 6 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 7 of Set 10 | barra patuca
# Processing Record 8 of Set 10 | batemans bay
# Processing Record 9 of Set 10 | la ferte-bernard
# Processing Record 10 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 11 of Set 10 | pitimbu
# Processing Record 12 of Set 10 | banyo
# Processing Record 13 of Set 10 | katherine
# Processing Record 14 of Set 10 | keti bandar
# Processing Record 15 of Set 10 | otradnoye
# Processing Record 16 of Set 10 | mihail kogalniceanu
# Processing Record 17 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 18 of Set 10 | masterton
# Processing Record 19 of Set 10 | coihaique
# Processing Record 20 of Set 10 | aland
# Processing Record 21 of Set 10 | marsa matruh
# Processing Record 22 of Set 10 | hamilton
# Processing Record 23 of Set 10 | henties bay
# Processing Record 24 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 10 | aksu
# Processing Record 26 of Set 10 | starodzhereliyevskaya
# Processing Record 27 of Set 10 | madera
# Processing Record 28 of Set 10 | leh
# Processing Record 29 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 10 | moron
# Processing Record 31 of Set 10 | kharitonovo
# Processing Record 32 of Set 10 | dubbo
# Processing Record 33 of Set 10 | sabang
# Processing Record 34 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 10 | provideniya
# Processing Record 36 of Set 10 | kalawit
# Processing Record 37 of Set 10 | cidreira
# Processing Record 38 of Set 10 | road town
# Processing Record 39 of Set 10 | porto belo
# Processing Record 40 of Set 10 | doha
# Processing Record 41 of Set 10 | jubayl
# City not found. Skipping...
# Processing Record 42 of Set 10 | sisimiut
# Processing Record 43 of Set 10 | kalmunai
# Processing Record 44 of Set 10 | lengshuijiang
# Processing Record 45 of Set 10 | kolobrzeg
# Processing Record 46 of Set 10 | bull savanna
# Processing Record 47 of Set 10 | yekaterinoslavka
# Processing Record 48 of Set 10 | chumikan
# Processing Record 49 of Set 10 | leeton
# Processing Record 50 of Set 10 | acajutla
# Processing Record 1 of Set 11 | myitkyina
# Processing Record 2 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 11 | puerto baquerizo moreno
# Processing Record 4 of Set 11 | jiuquan
# Processing Record 5 of Set 11 | uribia
# Processing Record 6 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 11 | balkhash
# Processing Record 8 of Set 11 | burnie
# Processing Record 9 of Set 11 | camargo
# Processing Record 10 of Set 11 | vyara
# Processing Record 11 of Set 11 | panguipulli
# Processing Record 12 of Set 11 | valdosta
# Processing Record 13 of Set 11 | varnavino
# Processing Record 14 of Set 11 | iqaluit
# Processing Record 15 of Set 11 | sinnamary
# Processing Record 16 of Set 11 | tecpan
# Processing Record 17 of Set 11 | panaba
# Processing Record 18 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 11 | balkanabat
# Processing Record 20 of Set 11 | chenghai
# Processing Record 21 of Set 11 | arandis
# Processing Record 22 of Set 11 | zunyi
# Processing Record 23 of Set 11 | alofi
# Processing Record 24 of Set 11 | sinjar
# Processing Record 25 of Set 11 | matola
# Processing Record 26 of Set 11 | maraa
# Processing Record 27 of Set 11 | aketi
# Processing Record 28 of Set 11 | bathsheba
# Processing Record 29 of Set 11 | moose factory
# Processing Record 30 of Set 11 | qena
# Processing Record 31 of Set 11 | ingham
# Processing Record 32 of Set 11 | mackay
# Processing Record 33 of Set 11 | raga
# Processing Record 34 of Set 11 | chicama
# Processing Record 35 of Set 11 | jalu
# Processing Record 36 of Set 11 | we
# City not found. Skipping...
# Processing Record 37 of Set 11 | charters towers
# Processing Record 38 of Set 11 | kamaishi
# Processing Record 39 of Set 11 | nemuro
# Processing Record 40 of Set 11 | patan
# Processing Record 41 of Set 11 | ribeira brava
# Processing Record 42 of Set 11 | novikovo
# Processing Record 43 of Set 11 | kibala
# Processing Record 44 of Set 11 | chingirlau
# Processing Record 45 of Set 11 | awjilah
# Processing Record 46 of Set 11 | lahaina
# Processing Record 47 of Set 11 | koch bihar
# Processing Record 48 of Set 11 | banda aceh
# Processing Record 49 of Set 11 | shishou
# Processing Record 50 of Set 11 | laguna
# Processing Record 1 of Set 12 | roald
# Processing Record 2 of Set 12 | basco
# Processing Record 3 of Set 12 | jiaocheng
# Processing Record 4 of Set 12 | tucuman
# Processing Record 5 of Set 12 | hobyo
# Processing Record 6 of Set 12 | sadovoye
# Processing Record 7 of Set 12 | manaure
# Processing Record 8 of Set 12 | balykshi
# Processing Record 9 of Set 12 | kalyan
# Processing Record 10 of Set 12 | mandurah
# Processing Record 11 of Set 12 | tingo maria
# Processing Record 12 of Set 12 | elizabeth city
# Processing Record 13 of Set 12 | degtyarsk
# Processing Record 14 of Set 12 | flinders
# Processing Record 15 of Set 12 | qujing
# Processing Record 16 of Set 12 | biryusinsk
# Processing Record 17 of Set 12 | townsville
# Processing Record 18 of Set 12 | tahta
# Processing Record 19 of Set 12 | yar-sale
# Processing Record 20 of Set 12 | cotonou
# Processing Record 21 of Set 12 | ponta delgada
# Processing Record 22 of Set 12 | slantsy
# Processing Record 23 of Set 12 | berlevag
# Processing Record 24 of Set 12 | san lawrenz
# Processing Record 25 of Set 12 | waitati
# Processing Record 26 of Set 12 | narsaq
# Processing Record 27 of Set 12 | rio gallegos
# Processing Record 28 of Set 12 | port hardy
# Processing Record 29 of Set 12 | ust-ilimsk
# Processing Record 30 of Set 12 | tigil
# Processing Record 31 of Set 12 | huntsville
# Processing Record 32 of Set 12 | egvekinot
# Processing Record 33 of Set 12 | odweyne
# Processing Record 34 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 35 of Set 12 | batasan
# Processing Record 36 of Set 12 | jiguani
# Processing Record 37 of Set 12 | aventura
# Processing Record 38 of Set 12 | rustenburg
# Processing Record 39 of Set 12 | merauke
# Processing Record 40 of Set 12 | shigony
# Processing Record 41 of Set 12 | weligama
# Processing Record 42 of Set 12 | birjand
# Processing Record 43 of Set 12 | moa
# Processing Record 44 of Set 12 | tezu
# Processing Record 45 of Set 12 | kaitong
# Processing Record 46 of Set 12 | ambovombe
# Processing Record 47 of Set 12 | mutoko
# Processing Record 48 of Set 12 | xitla
# City not found. Skipping...
# Processing Record 49 of Set 12 | mabaruma
# Processing Record 50 of Set 12 | shubarkuduk
# Processing Record 1 of Set 13 | chernyshevskiy
# Processing Record 2 of Set 13 | ulety
# Processing Record 3 of Set 13 | carutapera
# Processing Record 4 of Set 13 | basoko
# Processing Record 5 of Set 13 | cairns
# Processing Record 6 of Set 13 | gewane
# Processing Record 7 of Set 13 | hami
# Processing Record 8 of Set 13 | zhigalovo
# Processing Record 9 of Set 13 | urzhum
# Processing Record 10 of Set 13 | douglas
# Processing Record 11 of Set 13 | teseney
# Processing Record 12 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 13 of Set 13 | chiang klang
# Processing Record 14 of Set 13 | najran
# Processing Record 15 of Set 13 | khalkhal
# Processing Record 16 of Set 13 | keetmanshoop
# Processing Record 17 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 13 | chapais
# Processing Record 19 of Set 13 | grants pass
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 567

# %%
#convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cape Town -33.9258   18.4232     57.20        77           0
# 1         Fortuna  40.5982 -124.1573     66.00        82           1
# 2  Port Elizabeth -33.9180   25.5701     59.00        67          40
# 3       Busselton -33.6500  115.3333     51.01        98          98
# 4         Ballina -28.8667  153.5667     62.60        94          90
# 5          Albany  42.6001  -73.9662     53.01        76         100
# 6           Tiksi  71.6872  128.8694     30.31        83         100
# 7       Saskylakh  71.9167  114.0833     30.97        87         100
# 8    Punta Arenas -53.1500  -70.9167     42.80        93          90
# 9         Qaanaaq  77.4840  -69.3632     32.97        68          92
#
#    Wind Speed Current Description Country                 Date
# 0       10.36           clear sky      ZA  2021-04-30 20:24:00
# 1       16.11           clear sky      US  2021-04-30 20:24:01
# 2       13.80    scattered clouds      ZA  2021-04-30 20:24:01
# 3        3.83     overcast clouds      AU  2021-04-30 20:24:01
# 4        6.91          light rain      AU  2021-04-30 20:24:02
# 5        1.99     overcast clouds      US  2021-04-30 20:21:00
# 6        3.44     overcast clouds      RU  2021-04-30 20:20:21
# 7        9.22     overcast clouds      RU  2021-04-30 20:21:06
# 8        6.91          light rain      CL  2021-04-30 20:19:49
# 9        5.64     overcast clouds      GL  2021-04-30 20:24:02

# %%
#reorder the columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0       Cape Town      ZA  2021-04-30 20:24:00 -33.9258   18.4232     57.20
# 1         Fortuna      US  2021-04-30 20:24:01  40.5982 -124.1573     66.00
# 2  Port Elizabeth      ZA  2021-04-30 20:24:01 -33.9180   25.5701     59.00
# 3       Busselton      AU  2021-04-30 20:24:01 -33.6500  115.3333     51.01
# 4         Ballina      AU  2021-04-30 20:24:02 -28.8667  153.5667     62.60
#
#    Humidity  Cloudiness  Wind Speed
# 0        77           0       10.36
# 1        82           1       16.11
# 2        67          40       13.80
# 3        98          98        3.83
# 4        94          90        6.91

# %%
# Create the output file (CSV).
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
